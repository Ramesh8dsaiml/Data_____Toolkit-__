# %%
#!pip install bokeh
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c3000a90-1ec3-4f1a-98e0-d281ee23ccf7">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'], flowers['petal_width']) #circle for scatter plot
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[5], line 6
#       4 p.yaxis.axis_label = "petal_width"
#       5 p.circle(flowers['petal_length'], flowers['petal_width']) #circle for scatter plot
# ----> 6 show(p)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\model\model.py:492, in Model.references(self)
#     488 def references(self) -> set[Model]:
#     489     ''' Returns all ``Models`` that this object has references to.
#     490
#     491     '''
# --> 492     return set(collect_models(self))
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)    137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1046', ...).radius doesn't have a value set

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'], flowers['petal_width']) #line for line chart
show(p)
# Out:
#   <div id="ee3ea1a9-710f-4680-99c7-2ea5576c54da" data-root-id="p1044" style="display: contents;"></div>

# %%
x = [1, 2, 3, 4]
y = [3, 8, 4, 7]

p = figure(title="line_chart")
p.line(x, y)
show(p)
# Out:
#   <div id="ae32ba30-5740-4be2-a532-e565b721aa2b" data-root-id="p1087" style="display: contents;"></div>

# %%
x = [1, 2, 3, 4]
y = [3, 8, 4, 7]

p = figure(title="line_chart")
p.scatter(x, y, size = 20, fill_color = 'red', legend_label = )
show(p)
