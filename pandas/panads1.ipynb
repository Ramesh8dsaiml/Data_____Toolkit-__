# %% [markdown]
# ##### What is Pandas?
# Python library used for working with structured data sets (tables). It has functions for analyzing, cleaning, exploring, and manipulating data. Similar to data tables in SQL and Excel.

# %% [markdown]
# #### 0 install pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pandas
import pandas as pd

# %%
pd.__version__ # check installed pandas version
# Out:
# '2.3.3'

# %% [markdown]
# ##### What is Dataframe?
# It's a structured data constructed with rows and columns, similar to a SQL tables or Excel tables

# %% [markdown]
# #### 1 Create Dataframe

# %%
f = pd.DataFrame([11,22,33])
print(f)
# Out:
#     0
# 0  11
# 1  22
# 2  33

# %%
# using a List
df = pd.DataFrame([11,22,33], columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df)) # check data type
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# using Dictionary of Lists
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000]
}

# %%
data1 = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000],
    'monthlySalary': [900000, 700000, 500000, 300000],
    'yaerlySalary': [9000000, 7000000, 5000000, 3000000]
}

# %%
df1 =pd.DataFrame(data1)
print(df1 )
type (df1 )
# Out:
#        Name  Age  Salary  monthlySalary  yaerlySalary
# 0    Madhav   16   90000         900000       9000000
# 1  Vishakha   17   70000         700000       7000000
# 2    Lalita   18   50000         500000       5000000
# 3   Rishabh   19   30000         300000       3000000
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### 2 Basic Dataframe Understanding

# %%
df.head(4) # top rows
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df1.head(4)
# Out:
#        Name  Age  Salary  monthlySalary  yaerlySalary
# 0    Madhav   16   90000         900000       9000000
# 1  Vishakha   17   70000         700000       7000000
# 2    Lalita   18   50000         500000       5000000
# 3   Rishabh   19   30000         300000       3000000

# %%
df.tail(2) # last rows
# Out:
#       Name  Age  Salary
# 2   Lalita   18   50000
# 3  Rishabh   19   30000

# %%
df.shape # returns a tuple containing the shape of the DataFrame - rows & columns
# Out:
# (4, 3)

# %%
df.columns # list of column names in a dataframe
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df1.shape
# Out:
# (4, 5)

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'monthlySalary', 'yaerlySalary'], dtype='object')

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True) # rename column name/s

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df1.rename(columns={'Age':'umar'}, inplace=True)
df1
# Out:
#        Name  umar  Salary  monthlySalary  yaerlySalary
# 0    Madhav    16   90000         900000       9000000
# 1  Vishakha    17   70000         700000       7000000
# 2    Lalita    18   50000         500000       5000000
# 3   Rishabh    19   30000         300000       3000000

# %%
df.info()  # info method prints information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df1.info
# Out:
# <bound method DataFrame.info of        Name  umar  Salary  monthlySalary  yaerlySalary
# 0    Madhav    16   90000         900000       9000000
# 1  Vishakha    17   70000         700000       7000000
# 2    Lalita    18   50000         500000       5000000
# 3   Rishabh    19   30000         300000       3000000>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           4 non-null      object
#  1   umar           4 non-null      int64
#  2   Salary         4 non-null      int64
#  3   monthlySalary  4 non-null      int64
#  4   yaerlySalary   4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 292.0+ bytes

# %%
df.describe() # describe method generates descriptive statistics of DataFrame, only for numerical-value columns
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
df1.describe()
# Out:
#             umar        Salary  monthlySalary  yaerlySalary
# count   4.000000      4.000000       4.000000  4.000000e+00
# mean   17.500000  60000.000000  600000.000000  6.000000e+06
# std     1.290994  25819.888975  258198.889747  2.581989e+06
# min    16.000000  30000.000000  300000.000000  3.000000e+06
# 25%    16.750000  45000.000000  450000.000000  4.500000e+06
# 50%    17.500000  60000.000000  600000.000000  6.000000e+06
# 75%    18.250000  75000.000000  750000.000000  7.500000e+06
# max    19.000000  90000.000000  900000.000000  9.000000e+06

# %% [markdown]
# #### 3 Save and Load data from csv

# %%
df.to_csv('test_data')

# %%
df1.to_csv('test_data1.csv',index=False)

# %%
df.to_csv('Test_data.csv', index=False) # save file - export data frame
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.to_csv('Test_data.csv', index=False) # save file - export data frame
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\core\generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'Test_data.csv'

# %%
load_df= pd.read_csv('Test_data.csv') # load file - import dataframe
load_df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
load_df1= pd.read_csv('test_data1.csv')
print(load_df1)
# Out:
#        Name  umar  Salary  monthlySalary  yaerlySalary
# 0    Madhav    16   90000         900000       9000000
# 1  Vishakha    17   70000         700000       7000000
# 2    Lalita    18   50000         500000       5000000
# 3   Rishabh    19   30000         300000       3000000

# %% [markdown]
# #### 4 Rows & Columns - Selection

# %%
# select single column
df[['Name']]
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3   Rishabh

# %%
df1[['Name']]
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3   Rishabh

# %%
df1[['umar']]
# Out:
#    umar
# 0    16
# 1    17
# 2    18
# 3    19

# %%
# select multiple columns
df[['Name', 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3   Rishabh           30000

# %%
# select single row || loc - label based index
df.loc[df.Name=='Madhav']
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
# select multiple rows || loc - label based index
df.loc[(df.Name=='Madhav') & (df.Monthly_Salary>=50000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[0:2] #  when you can only use loc then nclude last row
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000

# %%
# Select Rows || iloc - index-value based , you can use iloc then no include last row 
# df.iloc[0]
df.iloc[0:2] # [start:stop:step]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %% [markdown]
# #### 5 Filter Dataframe - Filtering by column values

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df['Age'] >= 18 # it provide  the bool values
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
df[df['Age'] >= 18 ]
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df_age_filter = df[df['Age'] >= 18] # filter and store dataframe in a new variable

# %%
df_age_filter
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 50000)] # multiple filter conditions
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   18           50000

# %%
df.where(df['Age'] >= 18) # where function replace values in a DataFrame based on a condition
# Out:
#       Name   Age  Monthly_Salary
# 0      NaN   NaN             NaN
# 1      NaN   NaN             NaN
# 2   Lalita  18.0         50000.0
# 3  Rishabh  19.0         30000.0

# %%
df.where(df['Age'] >= 18, other = 'Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            18          50000
# 3       Rishabh            19          30000

# %% [markdown]
# #### 6 Rows and Columns - Operation (Add, update, delete)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           95000  CEO  19000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   4200.0

# %%
# Create a new column
df['Team'] = ['CEO', 'HR', 'CTO', 'DA']
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
# Add new columns using existing column/s
df['Bonus'] = df['Monthly_Salary'] * 0.20
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0

# %%
# Add new row - at the end of dataframe
df.loc[len(df)] = ['ABC', 21, 21000, 'IT', 2000]
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         1000000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0
# 5       ABC   21           21000   IT   2000.0
# 6       ABC   21           21000   IT   2000.0
# 7       ABC   21           21000   IT   2000.0

# %%
[len(df)]  # have a 5 rows
# Out:
# [8]

# %%
# update value in dataframe using index-name
df.loc[0, 'Monthly_Salary'] = 95000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           95000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0
# 5       ABC   21           21000   IT   2000.0
# 6       ABC   21           21000   IT   2000.0
# 7       ABC   21           21000   IT   2000.0

# %%
df.loc[0, 'Monthly_Salary'] = 1000000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16         1000000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0
# 5       ABC   21           21000   IT   2000.0
# 6       ABC   21           21000   IT   2000.0
# 7       ABC   21           21000   IT   2000.0

# %%
df.to_csv('Test_data.csv2', index=False)

# %%
load_df=pd.read_csv('test_data')
load_df
# Out:
#    Unnamed: 0      Name  Age  Monthly_Salary
# 0           0    Madhav   16           90000
# 1           1  Vishakha   17           70000
# 2           2    Lalita   18           50000
# 3           3   Rishabh   19           30000

# %%
# update value in dataframe using column-value
df.loc[df.Name=='Madhav','Monthly_Salary'] = 90000
df
# Out:
#        Name  Age  Monthly_Salary Team    Bonus
# 0    Madhav   16           90000  CEO  18000.0
# 1  Vishakha   17           70000   HR  14000.0
# 2    Lalita   18           50000  CTO  10000.0
# 3   Rishabh   19           30000   DA   6000.0
# 4       ABC   21           21000   IT   2000.0
# 5       ABC   21           21000   IT   2000.0
# 6       ABC   21           21000   IT   2000.0
# 7       ABC   21           21000   IT   2000.0

# %%
# delete value - rows and columns

# %%
# delete row using column-value filter
df = df.drop(df[df.Name == 'ABC'].index) # delete row, axis= 0

# %%
df[df.Name=='Madhav']
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Madhav   16           90000  CEO  18000.0

# %%
# delete row using index-name filter
df.drop(1, axis=0)
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Madhav   16           90000  CEO  18000.0
# 2   Lalita   18           50000  CTO  10000.0
# 3  Rishabh   19           30000   DA   6000.0

# %%
df.drop(1, axis=0)
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Madhav   16           90000  CEO  18000.0
# 2   Lalita   18           50000  CTO  10000.0
# 3  Rishabh   19           30000   DA   6000.0

# %%
df.drop('Bonus', axis=1, inplace=True) # delete one column
# df.drop(['Bonus', 'Team'], axis=1, inplace=True) # delete multiple columns

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
df.rename(columns={'Monthly_Salary': 'Salary'}, inplace=True) # rename column name

# %%
# sort values - order values in dataframe by asc or desc order
df.sort_values('Salary') #ascending order, by default
# Out:
#        Name  Age  Salary Team
# 3   Rishabh   19   30000   DA
# 2    Lalita   18   50000  CTO
# 1  Vishakha   17   70000   HR
# 0    Madhav   16   90000  CEO

# %%
# sort values in descending order
df.sort_values('Salary', ascending=False)
# Out:
#        Name  Age  Salary Team
# 0    Madhav   16   90000  CEO
# 1  Vishakha   17   70000   HR
# 2    Lalita   18   50000  CTO
# 3   Rishabh   19   30000   DA

# %% [markdown]
# #### 7 working with date value

# %%
# create a date column - date of joining
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']
df
# Out:
#        Name  Age  Salary Team         DOJ
# 0    Madhav   16   90000  CEO  2024-01-01
# 1  Vishakha   17   70000   HR  2024-01-15
# 2    Lalita   18   50000  CTO  2024-03-28
# 3   Rishabh   19   30000   DA  2024-03-03

# %%
df['DOJ'].dtype # object-type value
# Out:
# dtype('O')

# %%
df['DOJ'] = pd.to_datetime(df['DOJ']) # change to date-time type

# %%
df['DOJ'].dtype # date-time type
# Out:
# dtype('<M8[ns]')

# %%
df1 = df

# %%
# creating a new column with incorrect date format
df1['DOJ2'] = ['01-01-2025', '15-01-2025', '28-03-2025', '03-03-2025']
df1
# Out:
#        Name  Age  Salary Team        DOJ        DOJ2
# 0    Madhav   16   90000  CEO 2024-01-01  01-01-2025
# 1  Vishakha   17   70000   HR 2024-01-15  15-01-2025
# 2    Lalita   18   50000  CTO 2024-03-28  28-03-2025
# 3   Rishabh   19   30000   DA 2024-03-03  03-03-2025

# %%
df1['DOJ2'].dtype  # object-type value
# Out:
# dtype('O')

# %%
df1['DOJ2'] = pd.to_datetime(df1['DOJ2'], format = '%d-%m-%Y') # change to date-time type using date-format

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.drop('DOJ2', axis=0)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df = df.drop('DOJ2', axis=0)
#       2 df
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File d:\My_python\MY_jupyter_invionments\myenv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['DOJ2'] not found in axis"

# %%
# extract year, month, week, day
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Monday
# 1      Monday
# 2    Thursday
# 3      Sunday
# Name: DOJ, dtype: object

# %%
# create new column using month extract function from DOJ column
df['Month'] = df['DOJ'].dt.month

# %%
df
# Out:
#        Name  Age  Salary Team        DOJ  Month
# 0    Madhav   16   90000  CEO 2024-01-01      1
# 1  Vishakha   17   70000   HR 2024-01-15      1
# 2    Lalita   18   50000  CTO 2024-03-28      3
# 3   Rishabh   19   30000   DA 2024-03-03      3

# %%
df['DOJ'] + pd.Timedelta(days=90) # add 90 days to DOJ column
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
# #### 8 Handling Missing Values

# %%
df
# Out:
#        Name  Age  Salary Team        DOJ  Month
# 0    Madhav   16   90000  CEO 2024-01-01      1
# 1  Vishakha   17   70000   HR 2024-01-15      1
# 2    Lalita   18   50000  CTO 2024-03-28      3
# 3   Rishabh   19   30000   DA 2024-03-03      3

# %%
df.isnull() #  Detect missing values
# Out:
#     Name    Age  Salary   Team    DOJ  Month
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
import numpy as np  # to create null values below

# %%
df.loc[df.Name=='Rishabh', 'Salary'] = np.nan # adding a null value

# %%
df
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1
# 2    Lalita   18  50000.0  CTO 2024-03-28      3
# 3   Rishabh   19      NaN   DA 2024-03-03      3

# %%
df.isnull()
# Out:
#     Name    Age  Salary   Team    DOJ  Month
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False    True  False  False  False

# %%
df.isnull().sum() # count of null values by columns
# Out:
# Name      0
# Age       0
# Salary    1
# Team      0
# DOJ       0
# Month     0
# dtype: int64

# %%
df.fillna(0) # fill null values with 0
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1
# 2    Lalita   18  50000.0  CTO 2024-03-28      3
# 3   Rishabh   19      0.0   DA 2024-03-03      3

# %%
df.loc[df.Name=='Rishabh', 'Salary'] = 30000

# %%
df
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1
# 2    Lalita   18  50000.0  CTO 2024-03-28      3
# 3   Rishabh   19  30000.0   DA 2024-03-03      3

# %% [markdown]
# #### 9 Aggregation and Group By

# %%
df['Month'].value_counts() # frequency of values in month column
# Out:
# Month
# 1    2
# 3    2
# Name: count, dtype: int64

# %%
df[df['Month']==1].value_counts() # frequency of values in month column where month=1
# Out:
# Name      Age  Salary   Team  DOJ         Month
# Madhav    16   90000.0  CEO   2024-01-01  1        1
# Vishakha  17   70000.0  HR    2024-01-15  1        1
# Name: count, dtype: int64

# %%
# aggregation based on group by
df.groupby('Month')['Salary'].sum() # sum of salary by month
# Out:
# Month
# 1    160000.0
# 3     80000.0
# Name: Salary, dtype: float64

# %%
# different aggregation on different columns
df.groupby('Month').agg({'Salary': 'mean', 'Name': 'count'})
# Out:
#         Salary  Name
# Month
# 1      80000.0     2
# 3      40000.0     2

# %% [markdown]
# #### 10 Concatenate and Merge Dataframe (JOINS)

# %%
df1 = pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID':[1,2,2,4],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %% [markdown]
# ##### What is Concatenate:
# Combine objects along a particular axis.

# %%
# Concatenate: vertical / row level / top on top
pd.concat([df1, df2], axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
# Concatenate: horizontal / column level / side on side
pd.concat([df1, df2], axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %% [markdown]
# ##### Merge in Pandas
# Performs join operations similar to relational databases like SQL JOINS

# %%
# merge = join
pd.merge(df1, df2, how='inner', on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1, df2, how='inner', left_on='ID', right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %% [markdown]
# #### 11 AI and ChatGPT

# %%
df
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1
# 2    Lalita   18  50000.0  CTO 2024-03-28      3
# 3   Rishabh   19  30000.0   DA 2024-03-03      3

# %%
# Prompt to filter salary > 70000 and January employees

# %%
# Method-1: basic filter
df[(df['Month'] == 1) & (df['Salary'] >= 70000)]
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1

# %%
# Method-2: query method
df.query("Month == 1 and Salary >= 70000")
# Out:
#        Name  Age   Salary Team        DOJ  Month
# 0    Madhav   16  90000.0  CEO 2024-01-01      1
# 1  Vishakha   17  70000.0   HR 2024-01-15      1
