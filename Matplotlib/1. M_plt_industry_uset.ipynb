# %%
#why do we need visualisation? #summarisation of data
#matplotlib, seaborn, plotly, bokeh
#matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([ 0.75413802,  0.09123885, -0.98727732, -0.19263112, -1.53177349,
#        -0.15262623, -0.0097464 , -1.45100765, -0.74463975, -0.03332719,
#        -0.44818757,  1.08560062,  0.09585361, -0.44788529, -0.48161802,
#        -1.52907631,  0.10739559, -0.69062088, -0.54741344,  0.47831243,
#         0.84234724,  1.2464897 , -0.85145136,  0.06751107,  0.52416046,
#        -1.36004472,  0.03936147,  0.27110673, -1.1570866 ,  0.1653367 ,
#         0.89115596, -0.56057583, -0.44945017, -0.83541437, -0.20513074,
#         1.22011233, -0.04871088,  0.57019579, -1.28394357,  1.19819254,
#         0.56817775,  0.68053896, -0.42294651,  1.04942913,  0.74534139,
#        -1.64742213,  1.19362403, -1.56425155,  0.3922108 ,  0.28389453])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -0.115242
# 2024-07-12 -0.041046
# 2024-07-13  0.759928
# 2024-07-14  1.760044
# 2024-07-15 -0.621947
# ...              ...
# 2027-04-02 -1.095974
# 2027-04-03 -0.157395
# 2027-04-04 -1.372974
# 2027-04-05 -1.051855
# 2027-04-06 -0.817758
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #summary>> most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.97323709, 0.73057459, 0.51710421, 0.92357233, 0.57223617,
#        0.81538138, 0.35192079, 0.63156946, 0.53957163, 0.80621972,
#        0.04754365, 0.6375148 , 0.67953635, 0.20835747, 0.27062767,
#        0.72190073, 0.75067845, 0.47819645, 0.16335585, 0.75253099,
#        0.71075802, 0.76410087, 0.36606399, 0.38403114, 0.33875877,
#        0.90670445, 0.26381259, 0.28044822, 0.59700993, 0.67232359,
#        0.73750924, 0.14060521, 0.35298414, 0.28117195, 0.47788571,
#        0.46929085, 0.49091942, 0.38235295, 0.26244024, 0.86857993,
#        0.59297893, 0.4630126 , 0.63284801, 0.29265552, 0.301046  ,
#        0.75135823, 0.8373156 , 0.45165746, 0.84148711, 0.77264469])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.16343811, 0.50181689, 0.65924909, 0.03139556, 0.58075863,
#        0.64549012, 0.01733426, 0.56481724, 0.07875487, 0.74690423,
#        0.43919554, 0.21685485, 0.41606745, 0.90683783, 0.0035786 ,
#        0.18877421, 0.26442706, 0.284044  , 0.20433256, 0.62205184,
#        0.03747567, 0.42772881, 0.79528101, 0.59811258, 0.8771522 ,
#        0.34037229, 0.66765503, 0.40626869, 0.10596018, 0.67276812,
#        0.5112761 , 0.59300385, 0.03364186, 0.85516003, 0.48971027,
#        0.89332799, 0.02931736, 0.74209594, 0.86139307, 0.8569442 ,
#        0.98860154, 0.21494129, 0.93973243, 0.74697054, 0.17730082,
#        0.84526807, 0.59152279, 0.00419903, 0.30340926, 0.08880951])

# %%
#scatter plot >> A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x, y)

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
x, y
# Out:
# ([1, 2, 3, 4, 5], [5, 2, 7, 8, 1])

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y1 as tata motors")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))                            #plt.subplot(rows, columns, index)

plt.show()
                                                  # (rows, columns, position)

# %%
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))                           
plt.show()

# %%
fig, ax = plt.subplots(2,1)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous numerical data

data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, color = 'r', bins = 20)
plt.show()

# %%
#stacked histogram >> two histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([-0.57000704,  1.37690616,  1.52694718, ..., -0.61344995,
#        -0.94980641, -0.00221411], shape=(5000,))

# %%
data2
# Out:
# array([ 0.97947825,  5.67832108,  4.22231593, ...,  3.14174028,
#         3.96015233, -0.46910849], shape=(5000,))

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.42725557, 0.23566311, 0.50435295, 0.36821815, 0.45932032,
#        0.73515043, 0.3908517 , 0.57968931, 0.55002227, 0.84922199,
#        0.28474386, 0.96506782, 0.81095519, 0.78089792, 0.30081395,
#        0.32679639, 0.75361592, 0.48771059, 0.12987584, 0.92654951,
#        0.1274004 , 0.31091132, 0.25567526, 0.06940036, 0.2081992 ,
#        0.21712396, 0.42999781, 0.67501808, 0.62551831, 0.43258558,
#        0.36426319, 0.2043179 , 0.78033248, 0.54165543, 0.20185566,
#        0.14067698, 0.88012827, 0.30911915, 0.44504006, 0.7257483 ,
#        0.60370947, 0.4206704 , 0.52256959, 0.6068201 , 0.46111172,
#        0.88360606, 0.82392377, 0.88977383, 0.00253751, 0.67364074])

# %%
y
# Out:
# array([0.98913095, 0.56870791, 0.77017123, 0.59502103, 0.64587623,
#        0.54446372, 0.73159425, 0.56374555, 0.23944856, 0.75384674,
#        0.59640542, 0.6230664 , 0.10278041, 0.27098686, 0.87159051,
#        0.65202749, 0.89696976, 0.52980723, 0.43985742, 0.8303958 ,
#        0.34820461, 0.59309744, 0.36480418, 0.14469292, 0.82137144,
#        0.07650707, 0.95834604, 0.28101805, 0.90536021, 0.44067533,
#        0.76390867, 0.45318545, 0.32189782, 0.87016041, 0.36041831,
#        0.55169604, 0.14919147, 0.59121338, 0.61787708, 0.02980235,
#        0.19295964, 0.27947814, 0.90904579, 0.0110961 , 0.33798136,
#        0.20932563, 0.63993642, 0.46769945, 0.72534266, 0.9863029 ])

# %%
plt.scatter(x, y, c = 'r', marker = "X")

# %%
#bar plot >> To see the districution of categorical variables
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x, y, color = 'r') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.barh(x, y, color = 'r') #horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#pie char >> To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
#focus on one segment
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode)
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot >> 3 dimesion plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y=data["Balance"])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color = 'red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color = 'red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot  >> to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x242774f0a90>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x24275aab990>,
#  'cmins': <matplotlib.collections.LineCollection at 0x242774c6c50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x24276d14b10>}

# %% [raw]
# #area plot >> variables changed over time
# An area plot, also called a stacked area plot, is a type of data visualization that shows how
# various quantitative factors have changed over time while highlighting how they all work together to form the whole. It's particularly good for illustrating how elements of a whole change over time or along a continuous dimension.
# A layered representation of the data is produced in an area plot by layering many variables on top of one another. The cumulative influence of all levels provides insight into the overall trend. Each layer represents a separate category or variable.
# To distinguish between categories, the space beneath each layer is frequently colored.

# %%
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1, category2, category3, labels = ["category1", "category2", "category3",],
             colors = ["skyblue","lightgreen", "orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
